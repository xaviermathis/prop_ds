# %% [markdown]
# # LAB: Workflow de Datos. Limpieza y sumarización de datos para el Desafío 3.
#
# ## Introducción
#
# La idea de este lab es comenzar a trabajar con los datos del Desafío 3. Vamos a tratar de comenzar con el proceso de limpieza, sumarización y análisis exploratorio del dataset de Properatti. Como recordarán, el objetivo final es el desarrollo de un tasador automático a ser aplicado a las próximas propiedades que sean comercializadas por la empresa mediante un modelo de regresión. Como verán, el dataset está sumamente "sucio" y require un intenso proceso de limpieza.
#
# El dataset contiene información referida al primer semestre de 2017 de las propiedades comercializables por la empresa:
#
# * Fecha de creación
# * Tipo de la propiedad (house, apartment, ph)
# * Operación del aviso (sell, rent)
# * Nombre del lugar
# * Nombre del lugar + nombre de sus ‘padres’
# * ID de geonames del lugar (si está disponible)
# * Latitud,Longitud
# * Precio original del aviso
# * Moneda original del aviso (ARS, USD)
# * Precio del aviso en moneda local (ARS)
# * Precio aproximado en USD
# * Superficie en m²
# * Superficie cubierta en m²
# * Precio en USD/m²
# * Precio por m²
# * N° de piso, si corresponde
# * Ambientes
# * URL en Properati
# * Descripción
# * Título
# * URL de un thumbnail de la primer foto
#
#
# Una vez terminada la limpieza, aquellos que se animen pueden empezar a probar algunos modelos simples de regresión.
#
#
# ## Objetivos de aprendizaje
#
# * Practicar técnicas de limpieza de datos de tipo texto
# * Practicar conversiones de tipo de dato
# * Practicar rellenar datos faltantes con 0s o promedios
# * Practicar técnicas para trabajo con datos categóricos
# * Transformar datos a información útil
# * Realizar un primer análisis exploratorio
# * BONUS: realizar un primer modelo de regresión

# %%
% matplotlib inline
import matplotlib.pyplot as plt
import datetime
import numpy as np
import pandas as pd
import re

# %%
from ml_utils import plots

# %%
# Cargar la data
df = pd.read_csv('../data/properatti.csv')  # DATOS DE PROPIEDADES EN VENTA PROPERATI
print(df.columns)
df.head()
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail'],
#       dtype='object')
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat                        ...                          \
# 0 -34.661824                        ...
# 1 -34.903883                        ...
# 2 -34.652262                        ...
# 3 -34.647797                        ...
# 4 -38.002626                        ...
#
#    surface_covered_in_m2  price_usd_per_m2 price_per_m2  floor  rooms  \
# 0                   40.0       1127.272727  1550.000000    NaN    NaN
# 1                    NaN               NaN          NaN    NaN    NaN
# 2                   55.0       1309.090909  1309.090909    NaN    NaN
# 3                    NaN               NaN          NaN    NaN    NaN
# 4                   35.0       1828.571429  1828.571429    NaN    NaN
#
#    expenses                                      properati_url  \
# 0       NaN  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1       NaN  http://www.properati.com.ar/15bob_venta_depart...
# 2       NaN  http://www.properati.com.ar/15bod_venta_depart...
# 3       NaN  http://www.properati.com.ar/15boh_venta_ph_lin...
# 4       NaN  http://www.properati.com.ar/15bok_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...
#
# [5 rows x 26 columns]

# %%
b_norte_df = df[(df["state_name"] == "Capital Federal") & (df["property_type"]=="apartment") & (df["place_name"] == "Barrio Norte") | ((df["place_name"] == "Recoleta") | (df["place_name"] == "Retiro"))]
b_norte_df.head()
# Out:
#      Unnamed: 0 operation property_type    place_name  \
# 178         178      sell     apartment  Barrio Norte
# 200         200      sell     apartment      Recoleta
# 227         227      sell     apartment      Recoleta
# 255         255      sell     apartment      Recoleta
# 262         262      sell     apartment  Barrio Norte
#
#                       place_with_parent_names country_name       state_name  \
# 178  |Argentina|Capital Federal|Barrio Norte|    Argentina  Capital Federal
# 200      |Argentina|Capital Federal|Recoleta|    Argentina  Capital Federal
# 227      |Argentina|Capital Federal|Recoleta|    Argentina  Capital Federal
# 255      |Argentina|Capital Federal|Recoleta|    Argentina  Capital Federal
# 262  |Argentina|Capital Federal|Barrio Norte|    Argentina  Capital Federal
#
#      geonames_id                        lat-lon        lat  \
# 178    3436109.0          -34.594304,-58.403685 -34.594304
# 200    3429595.0        -34.5994274,-58.4015856 -34.599427
# 227    3429595.0  -34.5883487899,-58.3900529339 -34.588349
# 255    3429595.0        -34.5955984,-58.4127129 -34.595598
# 262    3436109.0        -34.5837821,-58.4042275 -34.583782
#
#                            ...                          surface_covered_in_m2  \
# 178                        ...                                           35.0
# 200                        ...                                          196.0
# 227                        ...                                          181.0
# 255                        ...                                           33.0
# 262                        ...                                           37.0
#
#      price_usd_per_m2 price_per_m2  floor  rooms  expenses  \
# 178               NaN  2657.142857    NaN    1.0       NaN
# 200       1938.775510  1938.775510    NaN    7.0       NaN
# 227       3246.073298  3425.414365    NaN    5.0       NaN
# 255       3636.363636  3636.363636    NaN    1.0       NaN
# 262       2648.648649  2648.648649    NaN    3.0       NaN
#
#                                          properati_url  \
# 178  http://www.properati.com.ar/15dd7_venta_depart...
# 200  http://www.properati.com.ar/15dhm_venta_depart...
# 227  http://www.properati.com.ar/15djy_venta_depart...
# 255  http://www.properati.com.ar/15dpd_venta_depart...
# 262  http://www.properati.com.ar/15dqa_venta_depart...
#
#                                            description  \
# 178  Corredor Responsable: Alejandro Botta - CUCICB...
# 200  Los equipos de aire acondicionado no estan inc...
# 227  Espectacular ubicación, al frente orientación ...
# 255  Excelente departamento a estrenar en recoleta ...
# 262  Departamento. Living/Comedor. 2 dormitorio(s)....
#
#                                                  title  \
# 178  Venta Mono dividido, amoblado, con muy buena r...
# 200  Semipiso. Living. Comedor. 4 dormitorio(s) 1 e...
# 227                      Recoleta Quintana Ancha 5 Amb
# 255               Sanchez de Bustamante 1300-Recoleta
# 262  Departamento. Living/Comedor. 2 dormitorio(s)....
#
#                                        image_thumbnail
# 178  https://thumbs4.properati.com/8/mpj88w7IJuYqlw...
# 200  https://thumbs4.properati.com/3/Iokg3DyiJu3v_e...
# 227  https://thumbs4.properati.com/2/AZGb5-RYl59wVS...
# 255  https://thumbs4.properati.com/0/FkdP8ymn9D3IuB...
# 262  https://thumbs4.properati.com/3/uPErfXjjHg3fyN...
#
# [5 rows x 26 columns]

# %%
b_norte_df = df[(df['state_name'] == 'Capital Federal') & (df['property_type'] == 'apartment') & ((df['place_name'] == 'Retiro') | (df['place_name'] == 'Recoleta') )]
b_norte_df.columns = ['indice', 'operacion', 'tipo_propiedad', 'barrio',
       'resumen_zona', 'pais', 'provincia', 'geonames_id',
       'latitud_longitud', 'latitud', 'longitud', 'precio', 'moneda',
       'cambio_aproximado', 'precio_usd', 'superficie_m2',
       'superficie_cubierta', 'precio_usd_m2', 'precio_m2', 'piso',
       'habitaciones', 'expensas', 'properati_url', 'descripcion', 'titulo',
       'imagen']
b_norte_df.head()
# Out:
#      indice operacion tipo_propiedad    barrio  \
# 200     200      sell      apartment  Recoleta
# 227     227      sell      apartment  Recoleta
# 255     255      sell      apartment  Recoleta
# 412     412      sell      apartment  Recoleta
# 422     422      sell      apartment  Recoleta
#
#                              resumen_zona       pais        provincia  \
# 200  |Argentina|Capital Federal|Recoleta|  Argentina  Capital Federal
# 227  |Argentina|Capital Federal|Recoleta|  Argentina  Capital Federal
# 255  |Argentina|Capital Federal|Recoleta|  Argentina  Capital Federal
# 412  |Argentina|Capital Federal|Recoleta|  Argentina  Capital Federal
# 422  |Argentina|Capital Federal|Recoleta|  Argentina  Capital Federal
#
#      geonames_id               latitud_longitud    latitud  \
# 200    3429595.0        -34.5994274,-58.4015856 -34.599427
# 227    3429595.0  -34.5883487899,-58.3900529339 -34.588349
# 255    3429595.0        -34.5955984,-58.4127129 -34.595598
# 412    3429595.0         -34.590333,-58.3864771 -34.590333
# 422    3429595.0        -34.5910354,-58.4006232 -34.591035
#
#                            ...                          superficie_cubierta  \
# 200                        ...                                        196.0
# 227                        ...                                        181.0
# 255                        ...                                         33.0
# 412                        ...                                        235.0
# 422                        ...                                        136.0
#
#      precio_usd_m2    precio_m2  piso  habitaciones  expensas  \
# 200    1938.775510  1938.775510   NaN           7.0       NaN
# 227    3246.073298  3425.414365   NaN           5.0       NaN
# 255    3636.363636  3636.363636   NaN           1.0       NaN
# 412    2936.170213  2936.170213   NaN           5.0       NaN
# 422    2700.000000  2779.411765   NaN           4.0       NaN
#
#                                          properati_url  \
# 200  http://www.properati.com.ar/15dhm_venta_depart...
# 227  http://www.properati.com.ar/15djy_venta_depart...
# 255  http://www.properati.com.ar/15dpd_venta_depart...
# 412  http://www.properati.com.ar/15ehd_venta_depart...
# 422  http://www.properati.com.ar/15eig_venta_depart...
#
#                                            descripcion  \
# 200  Los equipos de aire acondicionado no estan inc...
# 227  Espectacular ubicación, al frente orientación ...
# 255  Excelente departamento a estrenar en recoleta ...
# 412  2º piso al frente con balcón y grandes ventana...
# 422  Edificio de categoria en excelentes condicione...
#
#                                                 titulo  \
# 200  Semipiso. Living. Comedor. 4 dormitorio(s) 1 e...
# 227                      Recoleta Quintana Ancha 5 Amb
# 255               Sanchez de Bustamante 1300-Recoleta
# 412            Montevideo 1700 entre Alvear y Quintana
# 422                                 Departamento venta
#
#                                                 imagen
# 200  https://thumbs4.properati.com/3/Iokg3DyiJu3v_e...
# 227  https://thumbs4.properati.com/2/AZGb5-RYl59wVS...
# 255  https://thumbs4.properati.com/0/FkdP8ymn9D3IuB...
# 412  https://thumbs4.properati.com/7/mzfxgkFbcL6syg...
# 422  https://thumbs4.properati.com/2/-FUozvmum1Wy4n...
#
# [5 rows x 26 columns]

# %% [markdown]
# geonames_id pagina: http://www.geonames.org/3430787/warnham-flats.html

# %%
b_norte_df.shape
# Out:
# (1660, 26)

# %%
b_norte_filtrado = b_norte_df[['tipo_propiedad', 'barrio',
                               'latitud', 'longitud', 'precio', 'moneda',
       'cambio_aproximado', 'precio_usd', 'superficie_m2',
       'superficie_cubierta', 'precio_usd_m2', 'precio_m2', 'piso',
       'habitaciones', 'expensas', 'properati_url', 'descripcion', 'titulo']]
b_norte_filtrado.head()
# Out:
#     tipo_propiedad    barrio    latitud   longitud    precio moneda  \
# 200      apartment  Recoleta -34.599427 -58.401586  380000.0    USD
# 227      apartment  Recoleta -34.588349 -58.390053  620000.0    USD
# 255      apartment  Recoleta -34.595598 -58.412713  120000.0    USD
# 412      apartment  Recoleta -34.590333 -58.386477  690000.0    USD
# 422      apartment  Recoleta -34.591035 -58.400623  378000.0    USD
#
#      cambio_aproximado  precio_usd  superficie_m2  superficie_cubierta  \
# 200          6704910.0    380000.0          196.0                196.0
# 227         10939590.0    620000.0          191.0                181.0
# 255          2117340.0    120000.0           33.0                 33.0
# 412         12174705.0    690000.0          235.0                235.0
# 422          6669621.0    378000.0          140.0                136.0
#
#      precio_usd_m2    precio_m2  piso  habitaciones  expensas  \
# 200    1938.775510  1938.775510   NaN           7.0       NaN
# 227    3246.073298  3425.414365   NaN           5.0       NaN
# 255    3636.363636  3636.363636   NaN           1.0       NaN
# 412    2936.170213  2936.170213   NaN           5.0       NaN
# 422    2700.000000  2779.411765   NaN           4.0       NaN
#
#                                          properati_url  \
# 200  http://www.properati.com.ar/15dhm_venta_depart...
# 227  http://www.properati.com.ar/15djy_venta_depart...
# 255  http://www.properati.com.ar/15dpd_venta_depart...
# 412  http://www.properati.com.ar/15ehd_venta_depart...
# 422  http://www.properati.com.ar/15eig_venta_depart...
#
#                                            descripcion  \
# 200  Los equipos de aire acondicionado no estan inc...
# 227  Espectacular ubicación, al frente orientación ...
# 255  Excelente departamento a estrenar en recoleta ...
# 412  2º piso al frente con balcón y grandes ventana...
# 422  Edificio de categoria en excelentes condicione...
#
#                                                 titulo
# 200  Semipiso. Living. Comedor. 4 dormitorio(s) 1 e...
# 227                      Recoleta Quintana Ancha 5 Amb
# 255               Sanchez de Bustamante 1300-Recoleta
# 412            Montevideo 1700 entre Alvear y Quintana
# 422                                 Departamento venta

# %% [markdown]
# # Cantidad de datos de habitaciones faltantes

# %%
a = b_norte_filtrado["habitaciones"]
a.isnull().sum()
# Out:
# 668

# %%
b_norte_ambientes = b_norte_filtrado.copy()
un_ambiente_regex = r"monoambiente|mono-ambiente|un ambiente|1 ambiente"

has_1_ambiente = (b_norte_ambientes['descripcion'].str.lower().str.contains(un_ambiente_regex, regex=True))

dos_ambientes_regex = r"dos ambiente|2 ambiente|2ambiente"

has_2_ambientes = (b_norte_ambientes['descripcion'].str.lower().str.contains(dos_ambientes_regex, regex=True))

tres_ambientes_regex = r"tres ambiente|3 ambiente|3ambiente"

has_3_ambientes = (b_norte_ambientes['descripcion'].str.lower().str.contains(tres_ambientes_regex, regex=True))

cuatro_ambientes_regex = r"cuatro ambiente|4 ambiente|4ambiente"

has_4_ambientes = (b_norte_ambientes['descripcion'].str.lower().str.contains(cuatro_ambientes_regex, regex=True))

cinco_ambientes_regex = r"cinco ambiente|5 ambiente|5ambiente"

has_5_ambientes = (b_norte_ambientes['descripcion'].str.lower().str.contains(cinco_ambientes_regex, regex=True))

seis_ambientes_regex = r"seis ambiente|6 ambiente|6ambiente"

has_6_ambientes = (b_norte_ambientes['descripcion'].str.lower().str.contains(seis_ambientes_regex, regex=True))

siete_ambientes_regex = r"siete ambiente|7 ambiente|7ambiente"

has_7_ambientes = (b_norte_ambientes['descripcion'].str.lower().str.contains(siete_ambientes_regex, regex=True))


is_null_ = b_norte_ambientes['habitaciones'].isnull()

b_norte_ambientes.head()
# Out:
#     tipo_propiedad    barrio    latitud   longitud    precio moneda  \
# 200      apartment  Recoleta -34.599427 -58.401586  380000.0    USD
# 227      apartment  Recoleta -34.588349 -58.390053  620000.0    USD
# 255      apartment  Recoleta -34.595598 -58.412713  120000.0    USD
# 412      apartment  Recoleta -34.590333 -58.386477  690000.0    USD
# 422      apartment  Recoleta -34.591035 -58.400623  378000.0    USD
#
#      cambio_aproximado  precio_usd  superficie_m2  superficie_cubierta  \
# 200          6704910.0    380000.0          196.0                196.0
# 227         10939590.0    620000.0          191.0                181.0
# 255          2117340.0    120000.0           33.0                 33.0
# 412         12174705.0    690000.0          235.0                235.0
# 422          6669621.0    378000.0          140.0                136.0
#
#      precio_usd_m2    precio_m2  piso  habitaciones  expensas  \
# 200    1938.775510  1938.775510   NaN           7.0       NaN
# 227    3246.073298  3425.414365   NaN           5.0       NaN
# 255    3636.363636  3636.363636   NaN           1.0       NaN
# 412    2936.170213  2936.170213   NaN           5.0       NaN
# 422    2700.000000  2779.411765   NaN           4.0       NaN
#
#                                          properati_url  \
# 200  http://www.properati.com.ar/15dhm_venta_depart...
# 227  http://www.properati.com.ar/15djy_venta_depart...
# 255  http://www.properati.com.ar/15dpd_venta_depart...
# 412  http://www.properati.com.ar/15ehd_venta_depart...
# 422  http://www.properati.com.ar/15eig_venta_depart...
#
#                                            descripcion  \
# 200  Los equipos de aire acondicionado no estan inc...
# 227  Espectacular ubicación, al frente orientación ...
# 255  Excelente departamento a estrenar en recoleta ...
# 412  2º piso al frente con balcón y grandes ventana...
# 422  Edificio de categoria en excelentes condicione...
#
#                                                 titulo
# 200  Semipiso. Living. Comedor. 4 dormitorio(s) 1 e...
# 227                      Recoleta Quintana Ancha 5 Amb
# 255               Sanchez de Bustamante 1300-Recoleta
# 412            Montevideo 1700 entre Alvear y Quintana
# 422                                 Departamento venta

# %%
df = b_norte_filtrado.copy()
condition = is_null_ & has_1_ambiente
df.loc[condition,"habitaciones"] = df.loc[condition,'habitaciones'].fillna(1.0)

condition = is_null_ & has_2_ambientes
df.loc[condition,"habitaciones"] = df.loc[condition,'habitaciones'].fillna(2.0)

condition = is_null_ & has_3_ambientes
df.loc[condition,"habitaciones"] = df.loc[condition,'habitaciones'].fillna(3.0)

condition = is_null_ & has_4_ambientes
df.loc[condition,"habitaciones"] = df.loc[condition,'habitaciones'].fillna(4.0)

condition = is_null_ & has_5_ambientes
df.loc[condition,"habitaciones"] = df.loc[condition,'habitaciones'].fillna(5.0)

condition = is_null_ & has_6_ambientes
df.loc[condition,"habitaciones"] = df.loc[condition,'habitaciones'].fillna(6.0)

a = df["habitaciones"]
a.isnull().sum()
# Out:
# 329

# %%
b_norte_filtrado.shape

# %%
print(b_norte_filtrado["expensas"].dtype)
aux = (b_norte_filtrado["expensas"].iloc[0])
# Out:
# float64

# %%
print(aux)
# Out:
# nan

# %% [markdown]
# # Palabras abstractas positivas

# %%
positivo = ["luminoso", "espacioso", "buen estado", "amenities", "ammenities"]f

# %%
b_norte_expresion = b_norte_filtrado.copy()
b_norte_anios = b_norte_expresion.copy()
for palabra_pos in positivo:
    print("\n", palabra_pos.upper(),"\n")
    
    b_norte_expresion = b_norte_filtrado[(b_norte_filtrado['descripcion'].str.lower().str.contains(palabra_pos))]

    print("b_norte_pos filtrado cantidad: ", b_norte_expresion.shape[0])
    print()
    if len(b_norte_expresion)>0:
        print(b_norte_expresion.iloc[0]["descripcion"])
    else:
        print("No hubieron resultados")
    print("#################################","\n")
# Out:
#  LUMINOSO
#
# b_norte_pos filtrado cantidad:  562
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  ESPACIOSO
#
# b_norte_pos filtrado cantidad:  10
#
# Corredor Responsable: Uno Bienes Raices SRL - CUCICBA 4993 Contacto: Oscar Damián Esman - MLS ID # 420041128-232Departamento de Categoria a media Cuadra de Av. Santa Fe sobre calle Anchorena.  Semipiso 2AMB y 1/2 al frente con dependencia, balcón en un Segundo piso. Pleno Recoleta!  Espacioso Living-comedor con un pequeño ambiente que se puede usar como escritorio o playroom abierto. con frente a la calle Anchorena y contrafrente a pulmón.    Baño completo con disposición en suite o también, fuera de la habitación. Tiene un antebaño con doble circulación lo cual permite transformarlo en habitación con baño en suite o con entrada por el living.  Habitación amplia con ventana al contrafrente y placard con Buena capacidad de guardado.  Cocina con buen espacio, conexion para lavarropa, toilette y habitación de servicio (actualmente cuarto de guardado)  Calefacción por loza radiante - el departamento cuenta con línea telefónica.  Recientemente reciclado, buena altura de techos y con Buena luz y ventilación!  El edificio es del estilo Racionalista de categoría construido en los 60´s con servicios centrales.  APTO CREDITO - NO APTO PROFESIONAL  Expensas $ 4400.- ABL $360   Tiene excelente acceso a los transportes públicos  Colectivos: 12, 29, 39, 41, 61, 62, 64, 68, 99, 106, 109, 111, 118, 132, 140, 152, 188, 194 Subtes (Metro): AGÜERO (Línea D), PUEYRREDON (Línea D), SANTA FE (Línea H)
# #################################
#
#
#  BUEN ESTADO
#
# b_norte_pos filtrado cantidad:  115
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  AMENITIES
#
# b_norte_pos filtrado cantidad:  109
#
# Departamento de dos ambientes en Recoleta!Excelente ubicación, dormitorio con baño en suite.Living con cocina integrada y barra desayunadora.amplios placares, espacio para lavarropas. balcónedificio con amenities.sum, parrilla y jacuzziExpensas 1500
# #################################
#
#
#  AMMENITIES
#
# b_norte_pos filtrado cantidad:  2
#
# SOLO PARA EXIGENTES Distinguida torre Sanchez Elía. PREMIUMTodo luz y sol.Hermoso departamento elegantemente decorado.Servicio de Conserjería y Vigilancia  24 horas.Excelentes ammenities. Gimnasio. Sauna. Vestuarios. Solarium. Pileta. Cancha de paddle. Plaza de niños. Baulera.Palier privado a 2 ascensores. Ingreso al departamento con doble puerta  Hall de entrada 4,5 x 2  Living 7,3 x 5,2 a balcónComedor x 4,6 con puerta corrediza doble Escritorio 4,6 x 4,4 con puerta corrediza doble al palier de entrada y puerta corrediza al living Toilette y placard de recepción1er. Dormitorio 9 x 4 (master suite, con gran vestidor 3,4 x 4 y 2 baños, uno con hidromasaje doble) a balcón 7 x 1,2 - 2do. Dormitorio 4,5 x 4 (suite) - Antecocina 8 x 1,5 - Cocina 3,5 x 3,1 con comedor diario Lavadero independienteDependencia de ServicioDoble circulaciónPuerta de servicio
# #################################

# %%
interior_inmueble = ["living", "comedor", "cocina", "dormitorio", "baño", "cochera", "sum", "sala", "jardin", "jardín", "balcon", "balcón", "pileta", "gimnasio"]



# amenities, sum, gimnasio, pileta
# balcon

# %%
b_norte_expresion = b_norte_filtrado.copy()
b_norte_anios = b_norte_expresion.copy()
for palabra_pos in interior_inmueble:
    print("\n", palabra_pos.upper(),"\n")
    
    b_norte_expresion = b_norte_filtrado[(b_norte_filtrado['descripcion'].str.lower().str.contains(palabra_pos))]

    print("b_norte_pos filtrado cantidad: ", b_norte_expresion.shape[0])
    print()
    if len(b_norte_expresion)>0:
        print(b_norte_expresion.iloc[0]["descripcion"])
    else:
        print("No hubieron resultados")
    print("#################################","\n")
# Out:
#  LIVING
#
# b_norte_pos filtrado cantidad:  946
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  COMEDOR
#
# b_norte_pos filtrado cantidad:  939
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  COCINA
#
# b_norte_pos filtrado cantidad:  1209
#
# Espectacular ubicación, al frente orientación Este.En la mejor cuadra y de mayor categoría de la ciudad de Buenos Aires.Tiene muy buena luz porque la altura de la unidad supera los edificios linderos.Living en "L"Balcon corrido al frenteDormitorio principal al frenteCocina Comedor diarioLavadero independienteDependencia de servicioPalier privadoPlacard de recepciónPlacares de soporte2 baños completosToilette4 domitoriosDoble circulaciónCOCHERA DOBLEBauleraSeguridad 24hsReferencias de la zona:Palacio DuhauAlvear PalacePlaza Intendente Torcuato de AlvearCentro Cultural RecoletaCementerio de RecoletaRecoleta MallColectivos: 10, 17, 37, 59, 60, 61, 62, 67, 75, 92, 93, 101, 102, 108, 110, 124, 130Las medidas son Aproximadas y al solo efecto orientativo, las medidas reales surgirán del Título de Propiedad respectivo.- Importante: La venta del Inmueble referido se encuentra sujeta a la tramitación del Código de Oferta de Transferencia de Inmuebles (C.O.T.I.) por parte del propietario.
# #################################
#
#
#  DORMITORIO
#
# b_norte_pos filtrado cantidad:  1008
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  BAÑO
#
# b_norte_pos filtrado cantidad:  1182
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  COCHERA
#
# b_norte_pos filtrado cantidad:  570
#
# Espectacular ubicación, al frente orientación Este.En la mejor cuadra y de mayor categoría de la ciudad de Buenos Aires.Tiene muy buena luz porque la altura de la unidad supera los edificios linderos.Living en "L"Balcon corrido al frenteDormitorio principal al frenteCocina Comedor diarioLavadero independienteDependencia de servicioPalier privadoPlacard de recepciónPlacares de soporte2 baños completosToilette4 domitoriosDoble circulaciónCOCHERA DOBLEBauleraSeguridad 24hsReferencias de la zona:Palacio DuhauAlvear PalacePlaza Intendente Torcuato de AlvearCentro Cultural RecoletaCementerio de RecoletaRecoleta MallColectivos: 10, 17, 37, 59, 60, 61, 62, 67, 75, 92, 93, 101, 102, 108, 110, 124, 130Las medidas son Aproximadas y al solo efecto orientativo, las medidas reales surgirán del Título de Propiedad respectivo.- Importante: La venta del Inmueble referido se encuentra sujeta a la tramitación del Código de Oferta de Transferencia de Inmuebles (C.O.T.I.) por parte del propietario.
# #################################
#
#
#  SUM
#
# b_norte_pos filtrado cantidad:  143
#
# Excelente departamento a estrenar en recoleta , frente al hospital de niños Dr Ricardo Gutierrez , a metros de la Universidad de Palermo, a pocas cuadras de la estación Bulnes de la linea D , e innumerables lineas de colectivos q nos comunican a todas las partes d capital federal .El edificio cuenta con pileta , sum, laundry, losa radiante , agua caliente central , superficie de la propiedad 36.09m2 superficie cubierta 33m2, las unidades tienen la opcion de cochera por dolares U$S 36.000
# #################################
#
#
#  SALA
#
# b_norte_pos filtrado cantidad:  89
#
# Edificio de Gran categoría en la mejor zona de Recoleta, diseñado por Mario Roberto Alvarez. Gran recepción, de living con ventanal al contra frente con vista a jardines, comedor. Pisos de roble de eslabonia originales. Sala de televisión o escritorio, toilette. Amplia cocina con tres hornos, comedor diario separado por puertas de blindex, lavadero, sector de planchado y dependencias para dos personas con un baño. Dos dormitorios, el principal en suite con living intimo, vista a jardines al contra frente, vestidor y/o sala de masajes, baño compartimentado y jacuzzi, el segundo dormitorio en suite con biblioteca. Posee cinco cocheras, (1 en el 1 subsuerlo ; 2 en el segundo y 2 en el cuarto subsuelo ).Una baulera seguridad 24 horas.
# #################################
#
#
#  JARDIN
#
# b_norte_pos filtrado cantidad:  47
#
# Edificio de Gran categoría en la mejor zona de Recoleta, diseñado por Mario Roberto Alvarez. Gran recepción, de living con ventanal al contra frente con vista a jardines, comedor. Pisos de roble de eslabonia originales. Sala de televisión o escritorio, toilette. Amplia cocina con tres hornos, comedor diario separado por puertas de blindex, lavadero, sector de planchado y dependencias para dos personas con un baño. Dos dormitorios, el principal en suite con living intimo, vista a jardines al contra frente, vestidor y/o sala de masajes, baño compartimentado y jacuzzi, el segundo dormitorio en suite con biblioteca. Posee cinco cocheras, (1 en el 1 subsuerlo ; 2 en el segundo y 2 en el cuarto subsuelo ).Una baulera seguridad 24 horas.
# #################################
#
#
#  JARDÍN
#
# b_norte_pos filtrado cantidad:  45
#
# Piso de 8 ambientes, al frente con patio. Importante recepción, living apaisado y gran comedor. toilette de recepción. Cocina y Playroon con doble circulacion, muy cálido, patio con parrilla. Amplios dormitorios uno en suite. Hermosas vistas a jardín arbolado. Muy luminoso y silencioso. Categoría y buen gusto para casa en Santa Fe y Callao. Bajas expensas. Cochera en alquiler en la cuadra.
# #################################
#
#
#  BALCON
#
# b_norte_pos filtrado cantidad:  197
#
# Espectacular ubicación, al frente orientación Este.En la mejor cuadra y de mayor categoría de la ciudad de Buenos Aires.Tiene muy buena luz porque la altura de la unidad supera los edificios linderos.Living en "L"Balcon corrido al frenteDormitorio principal al frenteCocina Comedor diarioLavadero independienteDependencia de servicioPalier privadoPlacard de recepciónPlacares de soporte2 baños completosToilette4 domitoriosDoble circulaciónCOCHERA DOBLEBauleraSeguridad 24hsReferencias de la zona:Palacio DuhauAlvear PalacePlaza Intendente Torcuato de AlvearCentro Cultural RecoletaCementerio de RecoletaRecoleta MallColectivos: 10, 17, 37, 59, 60, 61, 62, 67, 75, 92, 93, 101, 102, 108, 110, 124, 130Las medidas son Aproximadas y al solo efecto orientativo, las medidas reales surgirán del Título de Propiedad respectivo.- Importante: La venta del Inmueble referido se encuentra sujeta a la tramitación del Código de Oferta de Transferencia de Inmuebles (C.O.T.I.) por parte del propietario.
# #################################
#
#
#  BALCÓN
#
# b_norte_pos filtrado cantidad:  652
#
# 2º piso al frente con balcón y grandes ventanales. Gran recepción. Living y comedor. Lugar de estar. 4 dormitorios, dos de ellos, uno en suite, dan a un lindo pulmón de manzana con mucho verde. Otro baño completo y toilette de recepción. Cocina y comedor diario. Lavadero independiente. Dependencia y baño de servicio. Servicios centrales. Expensas $4800. Opción cochera en alquiler.La presente oferta de venta está condicionada a la obtención del COTI por parte del propietario. Las medidas informadas son aproximadas y orientativas. Las medidas exactas surgirán del título de propiedad.Matriculado:Martín LottiCPI 2989
# #################################
#
#
#  PILETA
#
# b_norte_pos filtrado cantidad:  80
#
# Excelente departamento a estrenar en recoleta , frente al hospital de niños Dr Ricardo Gutierrez , a metros de la Universidad de Palermo, a pocas cuadras de la estación Bulnes de la linea D , e innumerables lineas de colectivos q nos comunican a todas las partes d capital federal .El edificio cuenta con pileta , sum, laundry, losa radiante , agua caliente central , superficie de la propiedad 36.09m2 superficie cubierta 33m2, las unidades tienen la opcion de cochera por dolares U$S 36.000
# #################################
#
#
#  GIMNASIO
#
# b_norte_pos filtrado cantidad:  81
#
# Departamento muy canchero y luminoso. Se ingresa por un hall de recepción a un gran living comedor que da a un balcón terraza con vista abierta al río. Segundo living o escritorio con grandes ventanales a vista panorámica. Puede ser un tercer dormitorio.  Baño completo que se utiliza toilette. Pasillo que lleva a los dos amplios dormitorios con grandes ventanales.  El principal en suite y otro con baño completo.Cocina con office, antecocina al lado comedor con mueble para vajilla, moderna cocina y lavadero.  Dormitorio de servicio con su baño.  Tiene dos cocheras. Amenities (cancha tenis, pileta, gimnasio, laundry) y seguridad 24 hs. Impecable.
# #################################

# %%
caracteristicas_inmueble = ["antigüedad", "antiguedad", "semipiso", "pozo", "anio", " año", "a estrenar", "nuevo", " piso"]

# %%
b_norte_expresion = b_norte_filtrado.copy()
b_norte_anios = b_norte_expresion.copy()
for palabra_pos in caracteristicas_inmueble:
    print("\n", palabra_pos.upper(),"\n")
    
    b_norte_expresion = b_norte_filtrado[(b_norte_filtrado['descripcion'].str.lower().str.contains(palabra_pos))]

    print("b_norte_pos filtrado cantidad: ", b_norte_expresion.shape[0])
    print()
    if len(b_norte_expresion)>0:
        print(b_norte_expresion.iloc[0]["descripcion"])
    else:
        print("No hubieron resultados")
    print("#################################","\n")
# Out:
#  ANTIGÜEDAD
#
# b_norte_pos filtrado cantidad:  68
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  ANTIGUEDAD
#
# b_norte_pos filtrado cantidad:  15
#
# Muy lindo Monoambiente Moderno y luminoso sobre calle laprida entre juncal y french Recoleta .2do Piso Frente Superficie Cubierta 32mts mas 3,5 de Balcon corrido (entra una mesa pequeÃ±a y 2 sillas ) posee cocina completa estilo americana con desayunador, piso flotante , 1 baÃ±o completo y calefaccion del tipo split frio calor todo en impecable estado y super moderno el edificio cuenta ademas con Laundry , piscina , solarium , sum y parrilla.antiguedad aproximada 5 aÃ±os .expensas bajas 1500opcion venta con muebles.+ info  lineas rotativaso a
# #################################
#
#
#  SEMIPISO
#
# b_norte_pos filtrado cantidad:  195
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  POZO
#
# b_norte_pos filtrado cantidad:  47
#
# EDIFICIO EN POZO ENTREGA ENERO 2019 AZCUENAGA Y MELO ( SOBRE AZCUENAGA 1600)ULTIMA UNIDAD DE 36MTS . 1 AMBIENTE CON BALCON,TODOS LOS AMENITIES. U$S 65660 EN EFECTIVO MAS 19 CUOTAS de $34.000INDEX POR C.A.C MENSUAL,
# #################################
#
#
#  ANIO
#
# b_norte_pos filtrado cantidad:  6
#
# UBICACIÓN- A 40 mts. de Av. Santa Fe con su numeroso transporte público- A 120 mts. de estación Agüero del Subte D- A 250 mts. del Shopping Alto Palermo- A 400 mts. de Av. Pueyrredón- A pasos de escuelas de excelencia, supermercados y zona comercial de Av. Santa Fe- En una zona de las de mayor seguridad de la Ciudad- 9 pisos con 18 unidades monoambientes con posibilidad de dividir en 2 Ambientes.- 9 pisos con 8 unidades de 3 dormitorios con dependencia- 1 unidad de tres ambientes con amplio balcón terraza- 2 dúplex con amplios patios y terrazas en piso 10° y 11°- 18 cocheras en planta baja y 1° subsueloEstructura de hormigón: En un todo de acuerdo a las normas establecidas en el CIRSOC.Muros: En el interior de la planta se ejecutarán tabiques divisorios de mampostería de ladrillo hueco del 8 y del 12 según el caso. Como divisoria entre distintas unidades funcionales se utilizará ladrillo común para conformar un muro de 15cm. de espesor. El perímetro exterior del edificio se realizará en hormigón de 0.15. Terminación interior en yeso o forro de Durlock.Cielorrasos: En estar, dormitorio y suites los cielorrasos serán de aplicados de yeso. En halles, pasillos, cocinas y baños los cielorrasos serán suspendidos de yeso o bien de Durlock, de acuerdo al proyecto.Solados y zócalos: En dormitorios se colocara piso flotante multilaminado de madera. En estares y pasos se colocará piso flotante multilaminado de madera en los casos de cocina independiente. Cuando se trate de cocina integrada se colocará piso de porcellanato de grandes dimensiones. Todos los ambientes llevarán zócalos de MDF pintados de 7 cm.Los baños y cocinas llevarán pisos de cerámica de primera calidad. Los balcones llevarán pisos de cerámica de primera calidad. Pisos de mármol o porcellanato en hall de acceso en PB.Revestimientos: Los baños serán revestidos en cerámica de primera calidad, mientras que los paramentos en cocina serán de yeso.Instalación de aire acondicionado: Sistema preparado para sistema de aire acondicionado frío/calor split.Ascensores: Se realizarán de acuerdo a la ley 962 “accesibilidad para todos”. Se utilizará tecnología de última generación con puertas y maniobras automáticas. Cabina revestida en acero inoxidable con espejo. Las puertas en PB serán de acero inoxidable. Carpintería metálica: La carpintería metálica exterior será de perfiles extruidos de aluminio anodizado o prepintado línea Modena o similar. Los marcos de las puertas serán de chapa doblada BWG nº 18.Vidrios: El espesor a utilizar estará en relación directa con las dimensiones de los paños a cubrir. DVH en dormitorios y en monoambientes, cuando den al frente.Carpintería de madera: Puertas de 45mm de espesor en MDF espesor 9mm pintadas con pomelas de bronce platil. Puertas de acceso a unidades y de escalera de acuerdo a normativa de incendio.Herrajes: Serán de primera calidad línea contemporánea, con cerradura de seguridad en el acceso a las unidades y pomelas de bronce.Placards: Frentes de placards corredizos espejados o similar, con lámina de seguridad en dormitorios, ejecutados en aluminio anodizado con guías superior e inferior y equipamiento interior básico.Muebles de cocina: Muebles bajo mesada y alacenas construídos en aglomerado o MDF enchapado en melamina colores a definir según diseño. Herrajes en aluminio anodizado natural.Cocina: Horno y/o anafe eléctrico según planos.Marmolería: Las mesadas de cocina serán de granito gris mara de 20 mm y alzadas sobre la mesada con pileta de acero inoxidable. En los baños se realizarán mesadas de mármol nacional tipo Crema Marfil con zócalo de 7cm en el perímetro. Las bachas de los toilettes serán blancas de apoyo. Pintura: Las unidades se entregarán pintadas con enduído completo, las paredes con látex, cielorrasos con látex para cielorrasos, la carpintería metálica con esmalte sintético y las puertas de madera y zócalos serán lustrados con sellador o bien pintadas con esmalte sintético.Instalación eléctrica: Según normas de Edenor y de ...
# #################################
#
#
#   AÑO
#
# b_norte_pos filtrado cantidad:  143
#
# Los equipos de aire acondicionado no estan incluidos en el precio de venta.Semipiso. Living. Comedor. 4 dormitorio(s) 1 en suite. 2 baño(s) 1 toilette(s). Entre medianeras. Al frente. S/av. principal.  Antiguo.  Luminoso.  En muy buen estado. Orientación Suroeste. Antigüedad 80 años.
# #################################
#
#
#  A ESTRENAR
#
# b_norte_pos filtrado cantidad:  65
#
# Excelente departamento a estrenar en recoleta , frente al hospital de niños Dr Ricardo Gutierrez , a metros de la Universidad de Palermo, a pocas cuadras de la estación Bulnes de la linea D , e innumerables lineas de colectivos q nos comunican a todas las partes d capital federal .El edificio cuenta con pileta , sum, laundry, losa radiante , agua caliente central , superficie de la propiedad 36.09m2 superficie cubierta 33m2, las unidades tienen la opcion de cochera por dolares U$S 36.000
# #################################
#
#
#  NUEVO
#
# b_norte_pos filtrado cantidad:  175
#
# Venta de Departamento 2 AMBIENTES en Recoleta, Capital FederalA unas cuadras de Buenos Aires Design, Plaza Francia, Cementerio de Recoleta. Importante zona gastronomica y de bares modernos. Facultad de derecho. Retiro. Sheraton. 5 minutos de microcentro. lineas de trenes y lineas de subterraneos, numerosas lineas de bus. y metrobus.. Se encuentra todo en perfectas condiciones, super Luminoso, muy ventilado. Aire acondicionado en cada ambiente Pisos nuevos. Baño y cocina amoblada. lavadero y living con balcon. Apto profesional Edificio con seguridad.El departamento esta todo nuevo .Ideal inversionista.El departamentos se encuentra alquilado desde marzo 2017 hasta marzo 2019 con una muy buena renta e inquilino de primera linea. Contrato altamente controlado y chequeado. -  - MACORD PROPIEDADES
# #################################
#
#
#   PISO
#
# b_norte_pos filtrado cantidad:  818
#
# 2º piso al frente con balcón y grandes ventanales. Gran recepción. Living y comedor. Lugar de estar. 4 dormitorios, dos de ellos, uno en suite, dan a un lindo pulmón de manzana con mucho verde. Otro baño completo y toilette de recepción. Cocina y comedor diario. Lavadero independiente. Dependencia y baño de servicio. Servicios centrales. Expensas $4800. Opción cochera en alquiler.La presente oferta de venta está condicionada a la obtención del COTI por parte del propietario. Las medidas informadas son aproximadas y orientativas. Las medidas exactas surgirán del título de propiedad.Matriculado:Martín LottiCPI 2989
# #################################

# %% [markdown]
# # Palabras de amenities objetivos

# %%
amenities = ["cocina", "lavadero", "al frente", " frente"]

# %%
b_norte_expresion = b_norte_filtrado.copy()
b_norte_anios = b_norte_expresion.copy()
for palabra_pos in amenities:
    print("\n", palabra_pos.upper(),"\n")
    
    b_norte_expresion = b_norte_filtrado[(b_norte_filtrado['descripcion'].str.lower().str.contains(palabra_pos))]

    print("b_norte_pos filtrado cantidad: ", b_norte_expresion.shape[0])
    print()
    if len(b_norte_expresion)>0:
        print(b_norte_expresion.iloc[0]["descripcion"])
    else:
        print("No hubieron resultados")
    print("#################################","\n")

# %% [markdown]
# # Ambientes

# %%
ambientes=["ambiente", "habitaci", "monoambiente", "mono-ambiente", "un ambiente", "1 ambiente", "2 ambiente", 'dos ambiente', "3 ambiente", "tres ambiente", "4 ambiente", "cuatro ambiente", "5 ambiente", "cinco ambiente", "6 ambiente", "seis ambiente"]

# %%
b_norte_ambientes = b_norte_filtrado.copy()

for palabra_pos in ambientes:
    print("\n", palabra_pos.upper(),"\n")
    
    b_norte_expresion = b_norte_ambientes[(b_norte_ambientes['descripcion'].str.lower().str.contains(palabra_pos))]
    
    
    
    print("b_norte_pos filtrado cantidad: ", b_norte_expresion.shape[0])
    print()
    if len(b_norte_expresion)>0:
        print(b_norte_expresion.iloc[0]["descripcion"])
    else:
        print("No hubieron resultados")
    print("#################################","\n")
# Out:
#  AMBIENTE
#
# b_norte_pos filtrado cantidad:  926
#
# Edificio de categoria en excelentes condiciones. Semipiso de 4 ambientes con dependencia de servicio, hall de recepcion con amplio placard, living y comedor separados uno del otro por una puerta de roble de dos hojas, hall de distribucion, 3 dormitorios de generosas dimensiones con amplios placares, un baño completo, toilette con bidet, ambos baños recien pintados, cocina con comedor diario, lavadero con tender aereo, habitacion de servicio con profusion de placares y baño de servicio. Pisos de roble en impecable estado en todo el departamento, doble circulacion, puerta principal y de servicio blindadas, amplia baulera individual y cochera fija incluida.
# #################################
#
#
#  HABITACI
#
# b_norte_pos filtrado cantidad:  151
#
# Edificio de categoria en excelentes condiciones. Semipiso de 4 ambientes con dependencia de servicio, hall de recepcion con amplio placard, living y comedor separados uno del otro por una puerta de roble de dos hojas, hall de distribucion, 3 dormitorios de generosas dimensiones con amplios placares, un baño completo, toilette con bidet, ambos baños recien pintados, cocina con comedor diario, lavadero con tender aereo, habitacion de servicio con profusion de placares y baño de servicio. Pisos de roble en impecable estado en todo el departamento, doble circulacion, puerta principal y de servicio blindadas, amplia baulera individual y cochera fija incluida.
# #################################
#
#
#  MONOAMBIENTE
#
# b_norte_pos filtrado cantidad:  160
#
# Excelente departamento Monoambiente a estrenar en recoleta , frente al hospital de niños Dr Ricardo Gutierrez , a metros de la Universidad de Palermo, a pocas cuadras de la estación Bulnes de la linea D , e innumerables lineas de colectivos q nos comunican a todas las partes d capital federal .El edificio cuenta con pileta , sum, laundry, losa radiante , agua caliente central , superficie de la propiedad 36m2 superficie cubierta 37m2, posibilidad de comprar cochera , no dude en consultar Aviso publicado por Sumaprop | Gestión Inmobiliaria Simple.
# #################################
#
#
#  MONO-AMBIENTE
#
# b_norte_pos filtrado cantidad:  2
#
# Venta de Departamento 1 AMBIENTE en Recoleta, Capital Federal-DESCRIPCIÓN:-MONO-AMBIENTE DIVIDIDO , MUY LUMINOSO CON VISTA AL FRENTE.-COCINA ELECTRICA.-BAÑO COMPLETO.-IMPECABLE ESTADO.-VIDEO:https://youtu.be/2BbS9_h4_8o -  - LOUNGE PROPIEDADES
# #################################
#
#
#  UN AMBIENTE
#
# b_norte_pos filtrado cantidad:  46
#
# VENTA DEPARTAMENTO 1 AMBIENTE RECOLETAUnidad de 30 m2 a estrenar ubicada a 200 mtrs de Av. Cnel. Diaz. Consta de un ambiente con placard con interiores espejado, balcón, cocina completa a gas y baño completo. Apto crédito y apto profesional.  Posee pisos de porcellanato y la instalación preparada para split. Cochera optativa. El edificio cuenta con piscina.LEPORE PROPIEDADES  LEPORE Propiedades S.A.CUIT : 33-60234274-9C.U.C.I.C.B.A. Matrícula Nº 931 (Sucursales Caballito - Palermo - Centro)AVISO LEGAL: Las descripciones arquitectónicas y funcionales, valores de expensas, impuestos y servicios, fotos y medidas de este inmueble son aproximados. Los datos fueron proporcionados por el propietario y pueden no estar actualizados a la hora de la visualización de este aviso por lo cual pueden arrojar inexactitudes y discordancias con las que surgen de los las facturas, títulos y planos legales del inmueble. El interesado deberá realizar las verificaciones respectivas previamente a la realización de cualquier operación, requiriendo por sí o sus profesionales las copias necesarias de la documentación que corresponda.Venta supeditada al cumplimiento por parte del propietario de los requisitos de la resolución general Nº 2371 de la AFIP (pedido de COTI) -  - LEPORE PROPIEDADES
# #################################
#
#
#  1 AMBIENTE
#
# b_norte_pos filtrado cantidad:  77
#
# VENTA DEPARTAMENTO 1 AMBIENTE RECOLETAUnidad de 30 m2 a estrenar ubicada a 200 mtrs de Av. Cnel. Diaz. Consta de un ambiente con placard con interiores espejado, balcón, cocina completa a gas y baño completo. Apto crédito y apto profesional.  Posee pisos de porcellanato y la instalación preparada para split. Cochera optativa. El edificio cuenta con piscina.LEPORE PROPIEDADES  LEPORE Propiedades S.A.CUIT : 33-60234274-9C.U.C.I.C.B.A. Matrícula Nº 931 (Sucursales Caballito - Palermo - Centro)AVISO LEGAL: Las descripciones arquitectónicas y funcionales, valores de expensas, impuestos y servicios, fotos y medidas de este inmueble son aproximados. Los datos fueron proporcionados por el propietario y pueden no estar actualizados a la hora de la visualización de este aviso por lo cual pueden arrojar inexactitudes y discordancias con las que surgen de los las facturas, títulos y planos legales del inmueble. El interesado deberá realizar las verificaciones respectivas previamente a la realización de cualquier operación, requiriendo por sí o sus profesionales las copias necesarias de la documentación que corresponda.Venta supeditada al cumplimiento por parte del propietario de los requisitos de la resolución general Nº 2371 de la AFIP (pedido de COTI) -  - LEPORE PROPIEDADES
# #################################
#
#
#  2 AMBIENTE
#
# b_norte_pos filtrado cantidad:  187
#
# Venta de Departamento 2 AMBIENTES en Recoleta, Capital FederalA unas cuadras de Buenos Aires Design, Plaza Francia, Cementerio de Recoleta. Importante zona gastronomica y de bares modernos. Facultad de derecho. Retiro. Sheraton. 5 minutos de microcentro. lineas de trenes y lineas de subterraneos, numerosas lineas de bus. y metrobus.. Se encuentra todo en perfectas condiciones, super Luminoso, muy ventilado. Aire acondicionado en cada ambiente Pisos nuevos. Baño y cocina amoblada. lavadero y living con balcon. Apto profesional Edificio con seguridad.El departamento esta todo nuevo .Ideal inversionista.El departamentos se encuentra alquilado desde marzo 2017 hasta marzo 2019 con una muy buena renta e inquilino de primera linea. Contrato altamente controlado y chequeado. -  - MACORD PROPIEDADES
# #################################
#
#
#  DOS AMBIENTE
#
# b_norte_pos filtrado cantidad:  56
#
# Departamento de dos ambientes en Recoleta!Excelente ubicación, dormitorio con baño en suite.Living con cocina integrada y barra desayunadora.amplios placares, espacio para lavarropas. balcónedificio con amenities.sum, parrilla y jacuzziExpensas 1500
# #################################
#
#
#  3 AMBIENTE
#
# b_norte_pos filtrado cantidad:  124
#
# 5° piso3 AmbientesContrafrenteMuy silencioso a pulmón de manzana muy amplio, verde y muy luminoso.Superficie total: 100m2Semi piso decoradoAmplio y super luminosoLiving Comedor2 dormitorios, ambos con placares de pared a pared2 baños completos con cerámica española, el principal con jacuzi de FerrumCocina completa con mesadas de Silestone y muebles importados de ItaliaLavaderoEdificio racional elegante y refaccionado a nuevo, con llave electrónica en puertas de entrada del edificio.Aire acondicionado Split frio/calor en todos los ambientes.Valor venta: USD 300.000.- (Opcional amoblado, con muebles de 1era calidad internacional)Expensas: $ 1.800Contactarse al  o al 15-
# #################################
#
#
#  TRES AMBIENTE
#
# b_norte_pos filtrado cantidad:  21
#
# UBICACIÓN- A 40 mts. de Av. Santa Fe con su numeroso transporte público- A 120 mts. de estación Agüero del Subte D- A 250 mts. del Shopping Alto Palermo- A 400 mts. de Av. Pueyrredón- A pasos de escuelas de excelencia, supermercados y zona comercial de Av. Santa Fe- En una zona de las de mayor seguridad de la Ciudad- 9 pisos con 18 unidades monoambientes con posibilidad de dividir en 2 Ambientes.- 9 pisos con 8 unidades de 3 dormitorios con dependencia- 1 unidad de tres ambientes con amplio balcón terraza- 2 dúplex con amplios patios y terrazas en piso 10° y 11°- 18 cocheras en planta baja y 1° subsueloEstructura de hormigón: En un todo de acuerdo a las normas establecidas en el CIRSOC.Muros: En el interior de la planta se ejecutarán tabiques divisorios de mampostería de ladrillo hueco del 8 y del 12 según el caso. Como divisoria entre distintas unidades funcionales se utilizará ladrillo común para conformar un muro de 15cm. de espesor. El perímetro exterior del edificio se realizará en hormigón de 0.15. Terminación interior en yeso o forro de Durlock.Cielorrasos: En estar, dormitorio y suites los cielorrasos serán de aplicados de yeso. En halles, pasillos, cocinas y baños los cielorrasos serán suspendidos de yeso o bien de Durlock, de acuerdo al proyecto.Solados y zócalos: En dormitorios se colocara piso flotante multilaminado de madera. En estares y pasos se colocará piso flotante multilaminado de madera en los casos de cocina independiente. Cuando se trate de cocina integrada se colocará piso de porcellanato de grandes dimensiones. Todos los ambientes llevarán zócalos de MDF pintados de 7 cm.Los baños y cocinas llevarán pisos de cerámica de primera calidad. Los balcones llevarán pisos de cerámica de primera calidad. Pisos de mármol o porcellanato en hall de acceso en PB.Revestimientos: Los baños serán revestidos en cerámica de primera calidad, mientras que los paramentos en cocina serán de yeso.Instalación de aire acondicionado: Sistema preparado para sistema de aire acondicionado frío/calor split.Ascensores: Se realizarán de acuerdo a la ley 962 “accesibilidad para todos”. Se utilizará tecnología de última generación con puertas y maniobras automáticas. Cabina revestida en acero inoxidable con espejo. Las puertas en PB serán de acero inoxidable. Carpintería metálica: La carpintería metálica exterior será de perfiles extruidos de aluminio anodizado o prepintado línea Modena o similar. Los marcos de las puertas serán de chapa doblada BWG nº 18.Vidrios: El espesor a utilizar estará en relación directa con las dimensiones de los paños a cubrir. DVH en dormitorios y en monoambientes, cuando den al frente.Carpintería de madera: Puertas de 45mm de espesor en MDF espesor 9mm pintadas con pomelas de bronce platil. Puertas de acceso a unidades y de escalera de acuerdo a normativa de incendio.Herrajes: Serán de primera calidad línea contemporánea, con cerradura de seguridad en el acceso a las unidades y pomelas de bronce.Placards: Frentes de placards corredizos espejados o similar, con lámina de seguridad en dormitorios, ejecutados en aluminio anodizado con guías superior e inferior y equipamiento interior básico.Muebles de cocina: Muebles bajo mesada y alacenas construídos en aglomerado o MDF enchapado en melamina colores a definir según diseño. Herrajes en aluminio anodizado natural.Cocina: Horno y/o anafe eléctrico según planos.Marmolería: Las mesadas de cocina serán de granito gris mara de 20 mm y alzadas sobre la mesada con pileta de acero inoxidable. En los baños se realizarán mesadas de mármol nacional tipo Crema Marfil con zócalo de 7cm en el perímetro. Las bachas de los toilettes serán blancas de apoyo. Pintura: Las unidades se entregarán pintadas con enduído completo, las paredes con látex, cielorrasos con látex para cielorrasos, la carpintería metálica con esmalte sintético y las puertas de madera y zócalos serán lustrados con sellador o bien pintadas con esmalte sintético.Instalación eléctrica: Según normas de Edenor y de ...
# #################################
#
#
#  4 AMBIENTE
#
# b_norte_pos filtrado cantidad:  109
#
# Edificio de categoria en excelentes condiciones. Semipiso de 4 ambientes con dependencia de servicio, hall de recepcion con amplio placard, living y comedor separados uno del otro por una puerta de roble de dos hojas, hall de distribucion, 3 dormitorios de generosas dimensiones con amplios placares, un baño completo, toilette con bidet, ambos baños recien pintados, cocina con comedor diario, lavadero con tender aereo, habitacion de servicio con profusion de placares y baño de servicio. Pisos de roble en impecable estado en todo el departamento, doble circulacion, puerta principal y de servicio blindadas, amplia baulera individual y cochera fija incluida.
# #################################
#
#
#  CUATRO AMBIENTE
#
# b_norte_pos filtrado cantidad:  2
#
# CODIGO:  ubicado en: Juan M Gutierrez 2700 -  Publicado por: BASMADJIAN PROPIEDADES. El precio es de USD 270000 null. SE VENDE EN RECOLETA, ,EXCELENTE Y LUMINOSO DEPARTAMENTO, CUATRO AMBIENTES, TRES DORMITORIOS Y DEPENDENCIA DE SERVICIO, COCINA COMPLETA CON MUEBLES DE PRIMERA, COMEDOR Y ESTAR CON HOGAR Y PISOS DE PINOTEA TARUGADO, DORMITORIOS CON PARQUET Y PLACARES, MUCHO LUGAR DE GUARDADO, DOS BALCONES UNO EN EL ESTAR Y OTRO EN LA HABITACION PRINCIPAL CON VISTAS ABIERTAS HACIA LA CIUDAD MUY BUENAS VISTAS Y POCO RUIDOSO, SE CALEFACCIONA POR LOSA RADIANTE CENTRAL ES APTO PROFESIONAL, EL EDIFICIO TIENE PISCINA Y SOLARIUM Y VIGILANCIA LAS 24 HORAS Y PORTERO. EL DEPTO POSEE UNA BAULERA Y HAY LUGAR DE ESTACIONAMIENTO PEGADO AL COLEGIO SAN AGUSTIN. . Publicado a través de Mapaprop
# #################################
#
#
#  5 AMBIENTE
#
# b_norte_pos filtrado cantidad:  30
#
# VENTA DEPARTAMENTO 5 AMBIENTES RECOLETAExcelente piso con entrada por Avda. Pueyrredon, al contrafrente se perfila hacia la calle Azcuenaga/ Cementerio Recoleta. Consta de gran living-comedor, 4 dormitorios, ppal en suite con vestidor y placard, Doble circulación, cocina con ante-cocina, comedor diario independiente, escritorio y 2 dependencias de servicios. Además cuenta baulera, cochera fija cubierta, seguridad nocturna en la semana y todo el día los fines de semana.Excelente ubicación rodeada de parque y jardines, a metros de las Avdas del Libertador y Las Heras en medio de un polo cultural donde se encuentran la Facultad de Derecho, Centro Cultural Recoleta, Museos de Bellas Artes, Palais de Glace.LEPORE PROPIEDADES consultas   LEPORE Propiedades S.A.CUIT : 33-60234274-9C.U.C.I.C.B.A. Matrícula Nº 931 (Sucursales Caballito - Palermo - Centro)AVISO LEGAL: Las descripciones arquitectónicas y funcionales, valores de expensas, impuestos y servicios, fotos y medidas de este inmueble son aproximados. Los datos fueron proporcionados por el propietario y pueden no estar actualizados a la hora de la visualización de este aviso por lo cual pueden arrojar inexactitudes y discordancias con las que surgen de los las facturas, títulos y planos legales del inmueble. El interesado deberá realizar las verificaciones respectivas previamente a la realización de cualquier operación, requiriendo por sí o sus profesionales las copias necesarias de la documentación que corresponda.Venta supeditada al cumplimiento por parte del propietario de los requisitos de la resolución general Nº 2371 de la AFIP (pedido de COTI) -  - LEPORE PROPIEDADES
# #################################
#
#
#  CINCO AMBIENTE
#
# b_norte_pos filtrado cantidad:  4
#
# Excelente piso en duplex Cinco ambientes, cuatro dormitoriosEstado Impecable, reciclado a nuevoMuy LuminosoEdificio racionalistaEdificio con seguridad 24 hs.
# #################################
#
#
#  6 AMBIENTE
#
# b_norte_pos filtrado cantidad:  4
#
# Gran inmueble a la venta de 6 ambientes en el corazón de recoleta , con cochera , baulera y dependencia ,muy luminoso con gran balcón aterrazado , en perfecto estado
# #################################
#
#
#  SEIS AMBIENTE
#
# b_norte_pos filtrado cantidad:  1
#
# Seis ambientes en excelente edificio sobre Quintana con espacio guardacoches.Primer piso al frente con balcón, hall de recepción, escritorio o playroom, living apaisado con chimenea, comedor con ventanales al balcón. Cuatro dormitorios, dos al contrafrente con balcón, un segundo escritorio o quinto dormitorio. Patio interno de 25mts, doble circulación interna.Amplia cocina con comedor diario y gran zona de servicio con dos dependencias, lavadero y baño. El departamento se encuentra a reciclar.La venta de este inmueble está sujeta a la tramitación del Código de Transferencia de Inmuebles (COTI), de conformidad con la normativa vigente (Res. AFIP 2371/08, 2439/08 y ccs.) por parte del propietario.---La venta de este inmueble está sujeta a la tramitación del Código de Transferencia de Inmuebles (COTI), de conformidad con la normativa vigente (Res. AFIP 2371/08, 2439/08 y ccs.) por parte del propietario.
# #################################

# %%
b_norte_ambientes["habitaciones"].value_counts(normalize=False)
# Out:
# 4.0     253
# 3.0     172
# 1.0     168
# 5.0     147
# 2.0     124
# 6.0      65
# 7.0      32
# 8.0      15
# 9.0       5
# 12.0      5
# 10.0      4
# 17.0      2
# Name: habitaciones, dtype: int64

# %%
b_norte_ambientes = b_norte_filtrado.copy()
un_ambiente_regex = r"monoambiente|mono-ambiente|un ambiente|1 ambiente"
#movies[(movies.duration >= 200) | (movies.genre == 'Drama')]

has_1_ambiente = (b_norte_ambientes['descripcion'].str.lower().str.contains(un_ambiente_regex, regex=True) and b_norte_ambientes["habitaciones"]==np.nan)

b_norte_ambientes['habitaciones'] = b_norte_ambientes['descripcion'].str.lower().str.contains(un_ambiente_regex, regex=True).apply(lambda x: 1 if has_1_ambiente)

#b_norte_ambientes["habitaciones"] = b_norte_ambientes[has_1_ambiente, 1.0, b_norte_ambientes["habitaciones"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-5d61f2ac9081> in <module>()
#       3 #movies[(movies.duration >= 200) | (movies.genre == 'Drama')]
#       4
# ----> 5 has_1_ambiente = (b_norte_ambientes['descripcion'].str.lower().str.contains(un_ambiente_regex, regex=True) and b_norte_ambientes["habitaciones"]==np.nan)
#       6
#       7 b_norte_ambientes['habitaciones'] = b_norte_ambientes['descripcion'].str.lower().str.contains(un_ambiente_regex, regex=True).apply(lambda x: 1 if has_1_ambiente else 0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#     953         raise ValueError("The truth value of a {0} is ambiguous. "
#     954                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 955                          .format(self.__class__.__name__))
#     956
#     957     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
palabra_clave = ("(.{0,10}" + "(\d+).{0,4}(piso)" + ".{0,10})")
anio_expression = re.compile(palabra_clave)

b_norte_anios = b_norte_filtrado.copy()



anios_mask = (b_norte_anios['descripcion'].str.lower().str.contains(palabra_clave, regex=True))
print(len(anios_mask))

b_norte_anios["has_dummy"] = np.where(anios_mask, True, False)

b_norte_anios["dummy"] = np.where(anios_mask, b_norte_anios['descripcion'].str.lower().str.extract(palabra_clave, regex=True), np.nan)

b_norte_anios.head(40)
# Out:
# /Users/xavier/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# 1660
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-cdc55fd4ae3f> in <module>()
#      11 b_norte_anios["has_dummy"] = np.where(anios_mask, True, False)
#      12
# ---> 13 b_norte_anios["dummy"] = np.where(anios_mask, b_norte_anios['descripcion'].str.lower().str.extract(palabra_clave, regex=True), np.nan)
#      14
#      15 b_norte_anios.head(40)
#
# TypeError: extract() got an unexpected keyword argument 'regex'

# %%
alto_palermo_coords = (34.3518, 58.24378) #34°35'18.3"S 58°24'37.8"W
facultad_medicina_coords = (34.35507, 58.23539) #34°35'50.7"S 58°23'53.9"W

# %%
def points_distance(point_1, point_2):
    x_1 = point_1[0]
    y_1 = point_1[1]
    x_2 = point_2[0]
    y_2 = point_2[1]
    distance = np.sqrt(((x_1-x_2)**2) + ((y_1-y_2)**2))
    return distance

# %% [markdown]
# # Limpiar el dataset
# Practiquemos nuestras capacidades para realizar limpieza de datos con el dataset de ventas de propiedades de Properatti. Si no recuerdan cómo hacer alguna de estas tareas, busquen en Internet o en clases anteriores de manipulación de datos.
#
# Buscamos que completen las siguientes tareas:
# * Quitar columnas redundantes
# * Convertir las variables categóricas numéricas a integer
# * Lidiar con los valores perdidos y/o erróneos en algunas variables clave:
#
#     + en este punto podría ser interesante realizar algo ligeramente más complejo que un simple rellenado en función de medias. Podría eventualmente imputar en función de medias condicionadas.
#         * por ejemplo, los campos `lat` y `long` tienen, también, muchos casos perdidos. Quizás una estrategia posible sería tratar de imputar las coordenadas con la media de los casos en el mismo `place_name` -barrio-.
#     + también podrían evaluar la posibilidad de extraer alguna información para completar los datos perdidos del campo "description" que contiene texto del aviso.
#         * por ejemplo, el campo `rooms` tiene una altísima cantidad de missing. Podrían intentar usando alguna expresión regex extraer información

# %%
b_norte_df.shape

# %% [markdown]
# # Filtrar los Datos
#
# En general, los mdoelos de precios suelen tener un carácter local. Es por eso que deberán elegir alguna zona o provincia para trabajar y estimar el modelo en base a dicha selección.

# %%
# Filtrar la zona elegida para estimar el modelo

# %% [markdown]
# # Análisis exploratorio
#
# Como estamos intentando predecir precios por metro cuadrado es importante realizar una primera vista y exploración de los datos.

# %%
# Calculo de correlacion entre features

# %%
# Analisis exploratorio, graficos...

# %% [markdown]
# ¿En qué barrios los precios por $m^2$ son más altos?

# %% [markdown]
# ¿En qué barrios hay una mayor cantidad de viviendas para su venta?

# %% [markdown]
# ¿ En qué barrios hay una mayor dispersión de precios?

# %% [markdown]
# ¿Qué tipo de propiedad presenta los mayores precios? ¿Cuál las mayores dispersiones?

# %% [markdown]
# Continua realizando un análisis exploratorio del dataset...

# %% [markdown]
# ## BONUS: Empezando con regresiones lineales...
#
# Si se atreven, podrían empezar a probar con algunos modelos de regresión no demasiado sofisticados. Seleccionen (o construyan) su variable dependiente ($Y$) y comiencen probando con pocas variables y modelos sencillos.
#
# Usen el estimador `LinearRegression` de submódulo `sklearn.linear_model`.
#
# Recuerden los pasos para comenzar a trabajar con estimadores en Scikit-Learn.
#
# 1. Elegir una clase de modelo importando la clase de estimador apropiado de Scikit-Learn.
# 2. Seleccionar los hiperparámetros del modelo instanciando la clase con los valores deseados.
# 3. Preparar los datos en una matriz de features y un array target, como vimos previamente.
# 4. Ajustar el modelo a los datos invocando el método fit() de la instancia del modelo.
# 5. Aplicar el modelo a nuevos datos:
#     * Para aprendizaje supervisado, frecuentemente predecimos labels para datos nuevos usando el método predict()
#     * Para aprendizaje no supervisado, frecuentemente transformamos o inferimos propiedades de los datos usando los métodos transform() o predict()
#
# ¿Qué pueden decir del ajuste y la capacidad predictiva de sus modelos?

# %%
from sklearn.linear_model import LinearRegression
